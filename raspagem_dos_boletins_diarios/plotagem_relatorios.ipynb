# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\uti_geral.csv', index_col='Data')

# %%
px.line(df, title='Taxa de ocupação em UTIs em Geral')

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\uti_covid-19.csv', index_col='Data')
px.line(df, title='Taxa de ocupação UTIs para Covid-19')

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\leitos_clinicos_geral.csv', index_col='Data')
px.line(df, title='Taxa de Ocupação de Leitos Clínicos em Geral')

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\leitos_clinicos_covid-19.csv', index_col='Data')
px.line(df, title='Taxa de Ocupação de Leitos Clínicos para Covid-19')

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\sala_vermelha_geral.csv', index_col='Data')
px.line(df, title='Taxa de Ocupação Sala Vermelha em Geral')

# %%
df = pd.read_csv(r'C:\Users\heylu\Documents\github\HeyLucasLeao.github.io\raspagem_dos_boletins_diarios\normalized_csvs\sala_vermelha_covid-19.csv', index_col='Data')
px.line(df, title='Taxa de Ocupação para Sala Vermelha para Covid-19')
